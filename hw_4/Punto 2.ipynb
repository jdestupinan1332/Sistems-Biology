# %% [markdown]
# *Integrantes:* Juan Estupiñán, Valentina Quiroga, Carlos Sanchez, Manuela Vanegas, Oscar Garzón

# %% [markdown]
# # PUNTO 2

# %% [markdown]
# #### a) Dibuje una distribución exponencial con media r e ilustre gráficamente por qué  la función
#
# $$\tau = \frac{1}{r} ln\left(\frac{1}{u}\right)$$
#
# donde u es un numero aleatorio uniformemente distribuido entre 0 y 1, produce una distribución exponencial.

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
r = arange(0.3,1.8, 0.3) #lista de 0.3 < r < 1.5  medias 
x = arange(0,5,0.01) #lista de vlores de x para poder graficar bien
for media in r:
    F = pow(e,-media*x) #por cada valor en r se hace esto
    plot (x,F)
xlabel('x')
ylabel('F(x)')
legend (r)

# %% [markdown]
# por esto, si juntamos ambas ecuaciones

# %% [markdown]
# o si se grafica según u, dejando r = 0.9, por ejemplo

# %%
u = random.uniform(0,1.0,50) #genera 50 números aleatorios con distribución continua [0,1)
tau = 1/0.9*log(1/u) #variación de tau según u)

# %%
plot(u,tau,'ko') #gráfica bien

# %% [markdown]
# #### b) Genere 500 números con distribución exponencial (r=10) y dibuje su histograma.

# %%
u = random.uniform(0,1,500)
tau = -1/10*log(u)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)

ax.hist(tau, 25, color= 'red')
plt.show()

# %% [markdown]
# #### c) Para dos reacciones independientes (A, B) con tasas promedio constantes de r=10 y k=5, genere una serie de tiempo donde ocurran al menos 50 eventos de cada tipo. Haga el histograma de los tiempos entre eventos del mismo tipo y entre eventos en general. Ajuste a cada histograma una exponencial y encuentre sus medias.

# %%
def reaction(tasa):
    lista1 =[]
    lista2 =[]
    tau = 0
    u = random.uniform(0,1,50)
    i= 0
    while i < 50:
        ran = u[i]
        tau = tau + log(1/ran)/tasa
        tu2 = log(1/ran)/tasa
        lista1.append(tau)
        lista2.append(tu2)
        i= i+1
    return lista1, lista2

# %%
x = arange(0,50,1)
rx1, tempos1 = reaction(10)
rx2, tempos2 = reaction(5)

# %%
plot(rx1,x)
plot(rx2,x)
xlabel('tiempo')
ylabel('reacciones')
legend(['r=10', 'k=5'])

# %%
x = arange(0,0.7,0.01) #lista de vlores de x para poder graficar bien
expo1 = 10*pow(e,-10*x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(tempos1, 20, color= 'blue')
plot(x, expo1, color = 'red')
title('eventos a')
plt.show()

# %%
x = arange(0,0.7,0.01) #lista de vlores de x para poder graficar bien
expo2 = 5*pow(e,-5*x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(tempos2, 20, color= 'green')
plot(x,expo2,color='red')
title('eventos b')
plt.show()

# %%
x = arange(0,0.7,0.01) #lista de vlores de x para poder graficar bien
expo3 = expo1 + expo2

fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(tempos2+tempos1, 20, color= 'cyan')
plot(x,expo3,color='red')
title('Eventos en general')
plt.show()

# %% [markdown]
# Entonces, la media de los eventos en general es 15

# %% [markdown]
# #### D) Genere una serie de tiempo para una reacción A con tasa promedio constantes de r=15, pero para cada evento genere un numero aleatorio con probabilidad 1/3 de cambiar el tipo de reacción a B. Haga el histograma de los tiempos entre eventos del mismo tipo y entre eventos en general. Ajuste a cada histograma una exponencial y encuentre sus medias.

# %%
def guill (tasa, A0, tau, tb):
    cantA = A0
    tbes = 0
    u1 = random.uniform()
    u2 = random.uniform()
    tau = tau + log(1/u1)/(cantA*tasa)
    tg = log(1/u1)/(cantA*tasa)
    ta = tg
    tb = tb + tg
    if u2 < 1/3.0 and cantA > 1:
        cantA = cantA-1
        tbes = tb
        tb = 0
        ta = 0

    
    return cantA, tau, tg, tbes, ta

# %%
lista = []
tiempos = []
tG = []
tB = []
tA = []
t=0
tb = 0
ta = 0
A=100
for i in range(200):
    A, t, tg, tb, ta= guill(15, A, t, tb)
    lista.append(A)
    tiempos.append(t)
    tG.append(tg)
    tB.append(tb)
    tA.append(ta)

# %%
plot (tiempos, lista)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(tG, 20, color= 'cyan')
title('Eventos en general')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(tB, 20, color= 'red')
title('Eventos B')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(tA, 20, color= 'green')
title('Eventos A')
plt.show()

# %%
expoa
# Out:
# array([ 15.        ,  14.97751687,  14.95506743,  14.93265165,
#         14.91026946,  14.88792082,  14.86560568,  14.84332399,
#         14.82107569,  14.79886074,  14.77667909,  14.75453069,
#         14.73241549,  14.71033343,  14.68828447,  14.66626856,
#         14.64428565,  14.62233568,  14.60041862,  14.57853441,
#         14.556683  ,  14.53486435,  14.51307839,  14.4913251 ,
#         14.4696044 ,  14.44791627,  14.42626064,  14.40463747,
#         14.38304671,  14.36148831,  14.33996223,  14.31846841,
#         14.29700681,  14.27557737,  14.25418006,  14.23281482,
#         14.2114816 ,  14.19018036,  14.16891104,  14.14767361,
#         14.126468  ,  14.10529419,  14.08415211,  14.06304171,
#         14.04196296,  14.02091581,  13.9999002 ,  13.97891609,
#         13.95796344,  13.93704219,  13.91615229,  13.89529371,
#         13.8744664 ,  13.8536703 ,  13.83290537,  13.81217157,
#         13.79146884,  13.77079715,  13.75015643,  13.72954666,
#         13.70896778,  13.68841974,  13.6679025 ,  13.64741602,
#         13.62696024,  13.60653512,  13.58614062,  13.56577669,
#         13.54544328,  13.52514034])
